# %% [markdown]
# # Experiment 01: Psychometric Stress Test
#
# This notebook contains the implementation and diagnostics for the Psychometric Stress Test, comparing ResNet18 and ViT architectures.
#
# ## Colab Implementation
# The full runnable code and raw outputs are available on Google Colab:
#
# [Run on Colab](https://colab.research.google.com/drive/1jo3duE-NQCSI0sbxEDCCiqS5vDHPmVFS?usp=sharing)
